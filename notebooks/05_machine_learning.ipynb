# %% [markdown]
# # 05 用户偏好机器学习预测
#
# 本 Notebook 为课程实训过程文件。

# %%
from pathlib import Path
import sys
sys.path.append(str(Path.cwd().parent))
import pandas as pd
from config import PROCESSED_DIR, MODEL_DIR, FIGURE_DIR
from src.ml_model import train_preference_model

df = pd.read_csv(PROCESSED_DIR / 'arena_cleaned.csv')
result = train_preference_model(df, MODEL_DIR, FIGURE_DIR)
result
# Out:
# {'status': 'ok',
#  'accuracy': 0.80625,
#  'train_size': 638,
#  'test_size': 160,
#  'labels': ['model_a', 'model_b', 'tie'],
#  'classification_report': {'model_a': {'precision': 0.8266666666666667,
#    'recall': 0.9117647058823529,
#    'f1-score': 0.8671328671328671,
#    'support': 68.0},
#   'model_b': {'precision': 0.7857142857142857,
#    'recall': 0.9295774647887324,
#    'f1-score': 0.8516129032258064,
#    'support': 71.0},
#   'tie': {'precision': 1.0,
#    'recall': 0.047619047619047616,
#    'f1-score': 0.09090909090909091,
#    'support': 21.0},
#   'accuracy': 0.80625,
#   'macro avg': {'precision': 0.8707936507936508,
#    'recall': 0.6296537394300443,
#    'f1-score': 0.6032182870892547,
#    'support': 160.0},
#   'weighted avg': {'precision': 0.8312440476190476,
#    'recall': 0.80625,
#    'f1-score': 0.7583665125197383,
#    'support': 160.0}}}
