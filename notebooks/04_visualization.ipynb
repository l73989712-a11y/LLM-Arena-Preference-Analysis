# %% [markdown]
# # 04 数据可视化
#
# 本 Notebook 为课程实训过程文件。

# %%
from pathlib import Path
import sys
sys.path.append(str(Path.cwd().parent))
import pandas as pd
from config import PROCESSED_DIR, FIGURE_DIR, HTML_DIR
from src.analysis import build_model_statistics
from src.visualization import create_static_charts, create_pyecharts

df = pd.read_csv(PROCESSED_DIR / 'arena_cleaned.csv')
model_stat = build_model_statistics(df)
create_static_charts(df, model_stat, FIGURE_DIR)
create_pyecharts(df, model_stat, HTML_DIR)
# Out:
# [WindowsPath('C:/Users/80561/Desktop/Data Analysis/DAPT/DA/LLM_Arena_Project_Portable/LLM_Arena_Project_Portable/outputs/html/model_score_top10.html'),
#  WindowsPath('C:/Users/80561/Desktop/Data Analysis/DAPT/DA/LLM_Arena_Project_Portable/LLM_Arena_Project_Portable/outputs/html/topic_distribution.html'),
#  WindowsPath('C:/Users/80561/Desktop/Data Analysis/DAPT/DA/LLM_Arena_Project_Portable/LLM_Arena_Project_Portable/outputs/html/battle_score_scatter.html')]
